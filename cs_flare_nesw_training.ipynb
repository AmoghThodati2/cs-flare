# %% [markdown]
# <a href="https://colab.research.google.com/github/leenad12/cs-flare/blob/master/cs_flare_nesw_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Aug  9 21:03:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1Ih3b5bUG1PK0DEUpXtC")
project = rf.workspace("charlotte-5ara9").project("cs-flare-new")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.37)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.7.4)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in -CS-FLARE-new-3 to yolov8:: 100%|██████████| 115175/115175 [00:02<00:00, 45021.50it/s]
# Extracting Dataset Version Zip to -CS-FLARE-new-3 in yolov8:: 100%|██████████| 3616/3616 [00:00<00:00, 3618.67it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8s-seg.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s-seg.pt to 'yolov8s-seg.pt'...
# 100% 22.8M/22.8M [00:00<00:00, 233MB/s]
# New https://pypi.org/project/ultralytics/8.2.75 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=segment, mode=train, model=yolov8s-seg.pt, data=/content/datasets/-CS-FLARE-new-3/data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/segment/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 18.7MB/s]
# 2024-08-09 21:32:51.018330: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-09 21:32:51.327264: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-09 21:32:51.419032: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2772092  ultralytics.nn.modules.head.Segment          [4, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 261 layers, 11791644 parameters, 11791628 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/segment/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 109MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# train: Scanning /content/datasets/-CS-FLARE-new-3/train/labels... 1258 images, 0 backgrounds, 0 corrupt: 100% 1258/1258 [00:00<00:00, 1267.74it/s]
# train: New cache created: /content/datasets/-CS-FLARE-new-3/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/core/composition.py:161: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/datasets/-CS-FLARE-new-3/valid/labels... 273 images, 0 backgrounds, 0 corrupt: 100% 273/273 [00:00<00:00, 1102.62it/s]
# val: WARNING ⚠️ /content/datasets/-CS-FLARE-new-3/valid/images/image208_jpg.rf.6e090fdd5a20e4455381c935dffbbede.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/datasets/-CS-FLARE-new-3/valid/images/image92_jpg.rf.349d5d28e630275bc26cfc8e8914d292.jpg: 1 duplicate labels removed
# val: New cache created: /content/datasets/-CS-FLARE-new-3/valid/labels.cache
# Plotting labels to runs/segment/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.31G     0.7768      1.541     0.8404      1.123         52        640: 100% 79/79 [00:40<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.13it/s]
#                    all        273        963      0.452      0.409      0.414      0.275      0.461      0.417      0.423      0.264
# Closing dataloader mosaic
# /usr/local/lib/python3.10/dist-packages/albumentations/core/composition.py:161: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.08G     0.8872      1.693     0.9444      1.219         33        640: 100% 79/79 [00:39<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:06<00:00,  1.48it/s]
#                    all        273        963      0.503      0.402       0.41      0.262      0.491      0.398      0.405      0.256
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.07G     0.8395      1.614     0.8647      1.183         34        640: 100% 79/79 [00:35<00:00,  2.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.10it/s]
#                    all        273        963      0.475      0.418      0.423      0.265      0.478      0.418      0.425      0.259
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.02G     0.8308      1.552     0.8149      1.169         37        640: 100% 79/79 [00:35<00:00,  2.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.19it/s]
#                    all        273        963      0.515      0.406      0.414      0.263      0.499      0.401      0.416      0.257
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/50       5.1G     0.7979      1.541     0.7931      1.156         40        640: 100% 79/79 [00:35<00:00,  2.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:05<00:00,  1.52it/s]
#                    all        273        963      0.508      0.423      0.433      0.277      0.521      0.428      0.439      0.269
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.12G     0.7914      1.525      0.762      1.153         40        640: 100% 79/79 [00:34<00:00,  2.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  1.92it/s]
#                    all        273        963      0.488      0.441      0.417      0.268      0.518      0.434      0.417      0.262
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.06G     0.7776       1.51     0.7545      1.139         28        640: 100% 79/79 [00:35<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.18it/s]
#                    all        273        963      0.546      0.391      0.421      0.273      0.557      0.397      0.428      0.268
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.05G     0.7643      1.455     0.7235      1.135         30        640: 100% 79/79 [00:35<00:00,  2.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:05<00:00,  1.77it/s]
#                    all        273        963      0.548       0.43      0.434       0.28      0.523      0.433      0.439      0.272
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.05G     0.7415      1.452     0.7042      1.117         39        640: 100% 79/79 [00:35<00:00,  2.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:05<00:00,  1.72it/s]
#                    all        273        963      0.535      0.414      0.439      0.288      0.536      0.424      0.446      0.279
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.07G     0.7223      1.417     0.6679      1.096         28        640: 100% 79/79 [00:35<00:00,  2.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.20it/s]
#                    all        273        963      0.524      0.421      0.429      0.272      0.528      0.431      0.437      0.266
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.08G     0.7122       1.39     0.6499      1.087         28        640: 100% 79/79 [00:35<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  1.92it/s]
#                    all        273        963      0.513      0.439       0.43      0.277      0.526      0.449      0.441      0.273
#
# 50 epochs completed in 0.647 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 23.9MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 23.9MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781148 parameters, 0 gradients, 42.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 9/9 [00:11<00:00,  1.29s/it]
#                    all        273        963      0.536      0.414      0.439      0.287      0.538      0.424      0.446      0.279
#                  brush        273        234      0.604      0.291      0.364      0.202      0.608      0.303      0.381      0.198
#                  grass        273        279      0.729      0.705      0.744      0.569       0.73      0.718       0.74      0.554
#            leaf litter        273         26      0.117     0.0769     0.0577     0.0194      0.115     0.0769     0.0544    0.00984
#                   tree        273        424      0.693      0.585       0.59      0.359      0.698      0.597      0.607      0.355
# Speed: 0.3ms preprocess, 6.3ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to runs/segment/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/segment/train/
# Out:
# args.yaml					    MaskF1_curve.png	 train_batch3161.jpg
# BoxF1_curve.png					    MaskP_curve.png	 train_batch3162.jpg
# BoxP_curve.png					    MaskPR_curve.png	 val_batch0_labels.jpg
# BoxPR_curve.png					    MaskR_curve.png	 val_batch0_pred.jpg
# BoxR_curve.png					    results.csv		 val_batch1_labels.jpg
# confusion_matrix_normalized.png			    results.png		 val_batch1_pred.jpg
# confusion_matrix.png				    train_batch0.jpg	 val_batch2_labels.jpg
# events.out.tfevents.1723239174.f6d354391f72.9328.0  train_batch1.jpg	 val_batch2_pred.jpg
# labels_correlogram.jpg				    train_batch2.jpg	 weights
# labels.jpg					    train_batch3160.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=segment mode=val model={HOME}/runs/segment/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781148 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/datasets/-CS-FLARE-new-3/valid/labels.cache... 273 images, 0 backgrounds, 0 corrupt: 100% 273/273 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/datasets/-CS-FLARE-new-3/valid/images/image208_jpg.rf.6e090fdd5a20e4455381c935dffbbede.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/datasets/-CS-FLARE-new-3/valid/images/image92_jpg.rf.349d5d28e630275bc26cfc8e8914d292.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 18/18 [00:12<00:00,  1.44it/s]
#                    all        273        963      0.535      0.414      0.439      0.287      0.536      0.424      0.446      0.279
#                  brush        273        234      0.602      0.291      0.364      0.203      0.606      0.303      0.381      0.197
#                  grass        273        279      0.729      0.703      0.743      0.569      0.731       0.72      0.741      0.554
#            leaf litter        273         26      0.117     0.0769     0.0571     0.0153      0.114     0.0769     0.0538     0.0101
#                   tree        273        424      0.693      0.585       0.59       0.36      0.694      0.597      0.607      0.354
# Speed: 6.2ms preprocess, 13.2ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model={HOME}/runs/segment/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=true
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11781148 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/271 /content/datasets/-CS-FLARE-new-3/test/images/image1001_jpg.rf.e64f92f0e98bb0ae2429367e65e30877.jpg: 640x640 4 grasss, 20.9ms
# image 2/271 /content/datasets/-CS-FLARE-new-3/test/images/image1002_jpg.rf.d20cf2af32f9bef39e6f3fa94932d56f.jpg: 640x640 2 grasss, 1 tree, 20.9ms
# image 3/271 /content/datasets/-CS-FLARE-new-3/test/images/image1004_jpg.rf.a2e138594b2c5678f90ac702615ed15f.jpg: 640x640 1 grass, 2 trees, 20.8ms
# image 4/271 /content/datasets/-CS-FLARE-new-3/test/images/image1006_jpg.rf.3448b9e6d75db70cc2366106d522e0a3.jpg: 640x640 1 grass, 3 trees, 20.9ms
# image 5/271 /content/datasets/-CS-FLARE-new-3/test/images/image1008_jpg.rf.c9a940e4229eaee62b6913052407c517.jpg: 640x640 2 brushs, 1 grass, 20.9ms
# image 6/271 /content/datasets/-CS-FLARE-new-3/test/images/image100_jpg.rf.906db73c343cec67083d54cb469ad79c.jpg: 640x640 2 grasss, 2 trees, 20.9ms
# image 7/271 /content/datasets/-CS-FLARE-new-3/test/images/image1010_jpg.rf.5a18bce794cb8e0e195175328ae4aae3.jpg: 640x640 1 grass, 1 tree, 20.8ms
# image 8/271 /content/datasets/-CS-FLARE-new-3/test/images/image1011_jpg.rf.496ec616f6215fc41a992ea12dd5e5ad.jpg: 640x640 1 grass, 20.8ms
# image 9/271 /content/datasets/-CS-FLARE-new-3/test/images/image1012_jpg.rf.e37de8bb50e3d2183914d145534525e8.jpg: 640x640 (no detections), 20.8ms
# image 10/271 /content/datasets/-CS-FLARE-new-3/test/images/image1013_jpg.rf.2ca07dd52b4cb4182ed9614d30f02bc9.jpg: 640x640 1 grass, 2 trees, 20.8ms
# image 11/271 /content/datasets/-CS-FLARE-new-3/test/images/image1014_jpg.rf.6b48ec624867d6ad2760a0b76cbd8b82.jpg: 640x640 1 brush, 1 grass, 1 tree, 16.3ms
# image 12/271 /content/datasets/-CS-FLARE-new-3/test/images/image1016_jpg.rf.7115b1d46b8b9ccf8d1174f8ab4a596e.jpg: 640x640 (no detections), 13.5ms
# image 13/271 /content/datasets/-CS-FLARE-new-3/test/images/image1020_jpg.rf.bbbde1a576757c7943a92254774572f2.jpg: 640x640 2 trees, 13.4ms
# image 14/271 /content/datasets/-CS-FLARE-new-3/test/images/image1021_jpg.rf.5a10f7c1d18c14f2cf9eab09cd9d0b46.jpg: 640x640 2 trees, 13.5ms
# image 15/271 /content/datasets/-CS-FLARE-new-3/test/images/image1022_jpg.rf.7e26784683b6ab297cccae305faa4082.jpg: 640x640 (no detections), 13.5ms
# image 86/271 /content/datasets/-CS-FLARE-new-3/test/images/image181_jpg.rf.b2818b94e277bf0acd3e210b7f65b2e7.jpg: 640x640 1 grass, 2 trees, 9.6ms
# image 87/271 /content/datasets/-CS-FLARE-new-3/test/images/image186_jpg.rf.24a71452d940fcc14d388077715fbd1f.jpg: 640x640 1 brush, 3 grasss, 3 trees, 9.6ms
# image 88/271 /content/datasets/-CS-FLARE-new-3/test/images/image188_jpg.rf.b7b4005b13eebb9472387fb4a506e8e4.jpg: 640x640 1 tree, 10.1ms
# image 89/271 /content/datasets/-CS-FLARE-new-3/test/images/image189_jpg.rf.38faeb7c94568ae973ef039cde8fbcc5.jpg: 640x640 2 brushs, 4 grasss, 1 tree, 10.4ms
# image 90/271 /content/datasets/-CS-FLARE-new-3/test/images/image192_jpg.rf.b4e497ac720be428bca8171acab36618.jpg: 640x640 1 brush, 1 grass, 3 trees, 9.6ms
# image 91/271 /content/datasets/-CS-FLARE-new-3/test/images/image195_jpg.rf.0e750d5ebb535d0e76329ea49b648509.jpg: 640x640 2 brushs, 2 grasss, 1 tree, 9.6ms
# image 92/271 /content/datasets/-CS-FLARE-new-3/test/images/image201_jpg.rf.74bf564c59bee64f1e42d639d79df563.jpg: 640x640 2 brushs, 1 grass, 1 tree, 9.6ms
# image 93/271 /content/datasets/-CS-FLARE-new-3/test/images/image202_jpg.rf.e17efd9a0ead8f5c2b559e967c40655c.jpg: 640x640 4 brushs, 2 trees, 9.6ms
# image 94/271 /content/datasets/-CS-FLARE-new-3/test/images/image205_jpg.rf.9fc035362e458162dc0e02341a33dbe7.jpg: 640x640 2 brushs, 3 trees, 9.7ms
# image 95/271 /content/datasets/-CS-FLARE-new-3/test/images/image212_jpg.rf.219c733f2ae5251719b84a23936bb999.jpg: 640x640 3 brushs, 2 grasss, 5 trees, 10.1ms
# image 96/271 /content/datasets/-CS-FLARE-new-3/test/images/image214_jpg.rf.81a1990aeabcc319af443521856e9df1.jpg: 640x640 2 brushs, 1 tree, 10.1ms
# image 97/271 /content/datasets/-CS-FLARE-new-3/test/images/image221_jpg.rf.82e5e5984aa1f3d1ee5785408738fae5.jpg: 640x640 1 grass, 2 trees, 10.3ms
# image 98/271 /content/datasets/-CS-FLARE-new-3/test/images/image227_jpg.rf.65aef1d51ce0f61f5b651d811a76ce2e.jpg: 640x640 1 brush, 5 grasss, 3 trees, 10.0ms
# image 99/271 /content/datasets/-CS-FLARE-new-3/test/images/image231_jpg.rf.8889a7f3ae8e185d0e86b3dbeb4c0b28.jpg: 640x640 2 grasss, 1 tree, 9.9ms
# image 100/271 /content/datasets/-CS-FLARE-new-3/test/images/image236_jpg.rf.220e0be65e4e23c7ef4b5a4990f01a0d.jpg: 640x640 3 grasss, 1 tree, 9.7ms
# image 101/271 /content/datasets/-CS-FLARE-new-3/test/images/image241_jpg.rf.2995a9e57124b76f1a241b8f17e20b8e.jpg: 640x640 2 grasss, 1 tree, 9.7ms
# image 102/271 /content/datasets/-CS-FLARE-new-3/test/images/image247_jpg.rf.24654ce7a70948b58ebae07e4ae9b845.jpg: 640x640 1 grass, 2 trees, 9.7ms
# image 119/271 /content/datasets/-CS-FLARE-new-3/test/images/image317_jpg.rf.54ab3fb82efd15b375d9e6e391f77cce.jpg: 640x640 2 grasss, 1 tree, 9.6ms
# image 120/271 /content/datasets/-CS-FLARE-new-3/test/images/image321_jpg.rf.a6ec47706a51ae51bfbe59bfa92a1e39.jpg: 640x640 1 brush, 2 grasss, 2 trees, 9.6ms
# image 121/271 /content/datasets/-CS-FLARE-new-3/test/images/image322_jpg.rf.a6121e1509335141df40551fc78a9be5.jpg: 640x640 4 grasss, 1 tree, 9.7ms
# image 122/271 /content/datasets/-CS-FLARE-new-3/test/images/image323_jpg.rf.061344d0b257dc62f6e60c1971bf5b04.jpg: 640x640 3 grasss, 2 trees, 11.9ms
# image 123/271 /content/datasets/-CS-FLARE-new-3/test/images/image330_jpg.rf.e41674b501f6bff3b134d1e12694e074.jpg: 640x640 1 brush, 1 grass, 1 tree, 9.9ms
# image 124/271 /content/datasets/-CS-FLARE-new-3/test/images/image331_jpg.rf.8ef0d057baeca6fc2f2cc9447a7e19d1.jpg: 640x640 1 grass, 4 trees, 9.9ms
# image 125/271 /content/datasets/-CS-FLARE-new-3/test/images/image334_jpg.rf.e02c49eda1b0e2161647cd9dfc5ee5b4.jpg: 640x640 2 grasss, 1 tree, 9.7ms
# image 126/271 /content/datasets/-CS-FLARE-new-3/test/images/image338_jpg.rf.ca5834adb8f861073d94149e0ea1fee1.jpg: 640x640 1 brush, 2 grasss, 6 trees, 9.6ms
# image 127/271 /content/datasets/-CS-FLARE-new-3/test/images/image340_jpg.rf.677d44d7f3eb2d2939665389d2cd336d.jpg: 640x640 1 brush, 4 grasss, 1 tree, 9.6ms
# image 128/271 /content/datasets/-CS-FLARE-new-3/test/images/image343_jpg.rf.f1794f21a59376918d5b9bb3a7c068b1.jpg: 640x640 3 grasss, 2 trees, 9.6ms
# image 129/271 /content/datasets/-CS-FLARE-new-3/test/images/image346_jpg.rf.a6eb7b045304d57d1bedbc57d13beb12.jpg: 640x640 2 grasss, 2 trees, 9.6ms
# image 130/271 /content/datasets/-CS-FLARE-new-3/test/images/image347_jpg.rf.ae27a88ad3573a8806c8f7eb101e3a1c.jpg: 640x640 3 grasss, 4 trees, 9.6ms
# image 131/271 /content/datasets/-CS-FLARE-new-3/test/images/image357_jpg.rf.0f4a23e840534ff4eb6fa776fc6c1556.jpg: 640x640 1 brush, 4 grasss, 1 tree, 9.6ms
# image 132/271 /content/datasets/-CS-FLARE-new-3/test/images/image358_jpg.rf.77610f3820322a9daaf8dc41b78907ff.jpg: 640x640 1 brush, 1 grass, 1 tree, 14.0ms
# image 133/271 /content/datasets/-CS-FLARE-new-3/test/images/image361_jpg.rf.d45098b49c9066b3f1feeb42b52b7c04.jpg: 640x640 8 grasss, 2 trees, 12.3ms
# image 134/271 /content/datasets/-CS-FLARE-new-3/test/images/image369_jpg.rf.4c8f5497f4103f1e4f9f7f2449651311.jpg: 640x640 1 tree, 14.8ms
# image 135/271 /content/datasets/-CS-FLARE-new-3/test/images/image370_jpg.rf.0325412c02295ecfcf614876e5d0d7b4.jpg: 640x640 1 grass, 2 trees, 13.5ms
# image 136/271 /content/datasets/-CS-FLARE-new-3/test/images/image371_jpg.rf.7e64ad8a90f100f23c45ceaac8b9657f.jpg: 640x640 3 grasss, 1 tree, 9.7ms
# image 137/271 /content/datasets/-CS-FLARE-new-3/test/images/image373_jpg.rf.30dd00b266c16f2fff0af861e652dd9c.jpg: 640x640 2 grasss, 1 tree, 10.0ms
# image 138/271 /content/datasets/-CS-FLARE-new-3/test/images/image375_jpg.rf.adbbeab1bf0270a443f7988e25b50673.jpg: 640x640 1 grass, 3 trees, 9.7ms
# image 139/271 /content/datasets/-CS-FLARE-new-3/test/images/image377_jpg.rf.d8ef5529d2212b97b558b27c204772ee.jpg: 640x640 4 grasss, 2 trees, 12.5ms
# image 140/271 /content/datasets/-CS-FLARE-new-3/test/images/image383_jpg.rf.c1b297a1eab195edd62318382101bb45.jpg: 640x640 1 grass, 1 tree, 12.4ms
# image 141/271 /content/datasets/-CS-FLARE-new-3/test/images/image400_jpg.rf.0b8f3f4af1a1219c95dec76cf352646d.jpg: 640x640 2 brushs, 1 grass, 1 tree, 9.7ms
# image 142/271 /content/datasets/-CS-FLARE-new-3/test/images/image406_jpg.rf.48059ce627b062557fa36d3510cfbed5.jpg: 640x640 1 grass, 1 tree, 9.7ms
# image 143/271 /content/datasets/-CS-FLARE-new-3/test/images/image408_jpg.rf.8f4b3ec3d5e673bb0b7ebf6f03b99788.jpg: 640x640 3 brushs, 1 grass, 2 trees, 9.7ms
# image 144/271 /content/datasets/-CS-FLARE-new-3/test/images/image411_jpg.rf.78dd2f5b198f5ff22a91898a42d8a6d4.jpg: 640x640 2 grasss, 1 tree, 9.7ms
# image 145/271 /content/datasets/-CS-FLARE-new-3/test/images/image411_jpg.rf.e1aae86a173767f3ed5e817a4d5a1324.jpg: 640x640 2 grasss, 1 tree, 9.9ms
# image 146/271 /content/datasets/-CS-FLARE-new-3/test/images/image413_jpg.rf.9e09d4d2b1669ade8f7cd019206d9367.jpg: 640x640 1 brush, 5 grasss, 2 trees, 12.4ms
# image 147/271 /content/datasets/-CS-FLARE-new-3/test/images/image419_jpg.rf.0f9630c70fb29da4327ac81c7a7bf967.jpg: 640x640 3 brushs, 3 trees, 9.7ms
# image 148/271 /content/datasets/-CS-FLARE-new-3/test/images/image420_jpg.rf.a17dc5b7971e7dc6edaf9e3789833a09.jpg: 640x640 1 brush, 2 grasss, 1 tree, 10.1ms
# image 149/271 /content/datasets/-CS-FLARE-new-3/test/images/image424_jpg.rf.e7f3858030e4eece04a98c4d33146a02.jpg: 640x640 1 tree, 10.0ms
# image 150/271 /content/datasets/-CS-FLARE-new-3/test/images/image42_jpg.rf.5e84decb0845c61a3c916d47b9e41b59.jpg: 640x640 1 grass, 1 tree, 9.7ms
# image 151/271 /content/datasets/-CS-FLARE-new-3/test/images/image432_jpg.rf.ea5406c7011321f17a2defa24456f61a.jpg: 640x640 1 tree, 9.7ms
# image 152/271 /content/datasets/-CS-FLARE-new-3/test/images/image436_jpg.rf.a51a98a4a42b8ea480766602f5a3c33b.jpg: 640x640 1 brush, 1 grass, 1 tree, 11.7ms
# image 153/271 /content/datasets/-CS-FLARE-new-3/test/images/image456_jpg.rf.5b596b638b01c8ed92833ba45ddc9f7a.jpg: 640x640 6 grasss, 3 trees, 9.8ms
# image 154/271 /content/datasets/-CS-FLARE-new-3/test/images/image459_jpg.rf.1f833afa2504fc82df4ce33dfd8144a7.jpg: 640x640 3 grasss, 2 trees, 9.6ms
# image 155/271 /content/datasets/-CS-FLARE-new-3/test/images/image463_jpg.rf.1b55554ce47c236efe1a806a8e67e126.jpg: 640x640 1 grass, 3 trees, 9.7ms
# image 156/271 /content/datasets/-CS-FLARE-new-3/test/images/image468_jpg.rf.a96928876068d6bce5d51e3b7d5dc743.jpg: 640x640 (no detections), 9.6ms
# image 157/271 /content/datasets/-CS-FLARE-new-3/test/images/image474_jpg.rf.098dae85df623eec06ec567b20d29079.jpg: 640x640 1 brush, 1 grass, 1 tree, 10.7ms
# image 158/271 /content/datasets/-CS-FLARE-new-3/test/images/image476_jpg.rf.511e0f9558c9110cf784594b02ae96d9.jpg: 640x640 6 grasss, 3 trees, 9.9ms
# image 159/271 /content/datasets/-CS-FLARE-new-3/test/images/image477_jpg.rf.0500a7e162c3c05f604a3187cd48afe9.jpg: 640x640 3 brushs, 2 grasss, 3 trees, 9.7ms
# image 160/271 /content/datasets/-CS-FLARE-new-3/test/images/image481_jpg.rf.48420be4261abc0caa988c8aa5d4d9b5.jpg: 640x640 1 tree, 9.7ms
# image 161/271 /content/datasets/-CS-FLARE-new-3/test/images/image483_jpg.rf.a5aef136aa0de243318dcb70bb26bad4.jpg: 640x640 2 grasss, 4 trees, 9.7ms
# image 162/271 /content/datasets/-CS-FLARE-new-3/test/images/image492_jpg.rf.0f174fe05d4d2f9abe95b53d81de5553.jpg: 640x640 3 brushs, 1 grass, 2 trees, 9.9ms
# image 163/271 /content/datasets/-CS-FLARE-new-3/test/images/image492_jpg.rf.cc80687d1d7035185d8616f7be99bf92.jpg: 640x640 2 brushs, 1 grass, 1 tree, 10.2ms
# image 164/271 /content/datasets/-CS-FLARE-new-3/test/images/image495_jpg.rf.001f9a92eb5867a51d98b6e62c53f448.jpg: 640x640 1 grass, 2 trees, 9.6ms
# image 165/271 /content/datasets/-CS-FLARE-new-3/test/images/image506_jpg.rf.6f38fc27873fb5918f6faa9515ed7975.jpg: 640x640 1 grass, 2 trees, 9.8ms
# image 166/271 /content/datasets/-CS-FLARE-new-3/test/images/image512_jpg.rf.56a7a8630b89ed2d71a70d96ba5a2fb3.jpg: 640x640 4 brushs, 5 grasss, 1 tree, 9.7ms
# image 167/271 /content/datasets/-CS-FLARE-new-3/test/images/image514_jpg.rf.19e67d002873d55f21f30677243bd8a8.jpg: 640x640 3 grasss, 3 trees, 9.7ms
# image 168/271 /content/datasets/-CS-FLARE-new-3/test/images/image517_jpg.rf.00eda54dab97dc68dc3d0c72f1599cb4.jpg: 640x640 1 grass, 2 trees, 18.7ms
# image 169/271 /content/datasets/-CS-FLARE-new-3/test/images/image525_jpg.rf.7dfe10906a5018b55e89d41db1bd2b14.jpg: 640x640 2 brushs, 1 grass, 1 tree, 9.6ms
# image 170/271 /content/datasets/-CS-FLARE-new-3/test/images/image525_jpg.rf.f6cb555bd60fa5cb4e93edec823f9712.jpg: 640x640 2 brushs, 1 grass, 1 tree, 9.6ms
# image 171/271 /content/datasets/-CS-FLARE-new-3/test/images/image528_jpg.rf.5e1c0bdb19078321f024c5498f0a27e8.jpg: 640x640 3 brushs, 2 trees, 10.1ms
# image 172/271 /content/datasets/-CS-FLARE-new-3/test/images/image530_jpg.rf.f2fda1c57ca5bba9a27fb979087304d0.jpg: 640x640 1 brush, 3 trees, 10.7ms
# image 173/271 /content/datasets/-CS-FLARE-new-3/test/images/image532_jpg.rf.f4e5e6adc5414a339d7b654034ec17de.jpg: 640x640 (no detections), 9.8ms
# image 174/271 /content/datasets/-CS-FLARE-new-3/test/images/image535_jpg.rf.49baf05df01f420ca4878cdf6825ec46.jpg: 640x640 1 grass, 2 trees, 9.8ms
# image 175/271 /content/datasets/-CS-FLARE-new-3/test/images/image536_jpg.rf.12100feea678c7d5478341a16bef0b43.jpg: 640x640 1 brush, 1 grass, 1 tree, 10.0ms
# image 176/271 /content/datasets/-CS-FLARE-new-3/test/images/image537_jpg.rf.562a86dc01542789b31c208e1dea2918.jpg: 640x640 3 brushs, 1 grass, 2 trees, 10.2ms
# image 177/271 /content/datasets/-CS-FLARE-new-3/test/images/image555_jpg.rf.06c38f1ad83460ac166f3144dc7ed4ec.jpg: 640x640 1 grass, 1 tree, 9.8ms
# image 178/271 /content/datasets/-CS-FLARE-new-3/test/images/image556_jpg.rf.360a4407e6d8debab05c68ab4b552707.jpg: 640x640 1 grass, 2 trees, 13.0ms
# image 179/271 /content/datasets/-CS-FLARE-new-3/test/images/image556_jpg.rf.ab9511ce7fa04fa6099cb130dc9a83f8.jpg: 640x640 1 grass, 1 tree, 11.8ms
# image 180/271 /content/datasets/-CS-FLARE-new-3/test/images/image558_jpg.rf.1a5aea0422c56655e423ca72e8c25b2c.jpg: 640x640 2 grasss, 2 trees, 10.2ms
# image 181/271 /content/datasets/-CS-FLARE-new-3/test/images/image568_jpg.rf.bc43bee39072d528065ecad48f745678.jpg: 640x640 2 grasss, 1 tree, 12.6ms
# image 182/271 /content/datasets/-CS-FLARE-new-3/test/images/image573_jpg.rf.03adf14f8c9f705f8b6bf323cac50e8a.jpg: 640x640 2 trees, 12.0ms
# image 183/271 /content/datasets/-CS-FLARE-new-3/test/images/image574_jpg.rf.47551003c2663c223d7ea99617818a8d.jpg: 640x640 1 brush, 16.9ms
# image 184/271 /content/datasets/-CS-FLARE-new-3/test/images/image584_jpg.rf.2ec33ca117ce616fc6f9518409f68de7.jpg: 640x640 2 trees, 13.7ms
# image 185/271 /content/datasets/-CS-FLARE-new-3/test/images/image599_jpg.rf.767a77f1004bc14d01a034c5f9a07952.jpg: 640x640 2 brushs, 11.6ms
# image 186/271 /content/datasets/-CS-FLARE-new-3/test/images/image601_jpg.rf.97afb302e86520e3d5c43b47d50107fa.jpg: 640x640 2 brushs, 10.2ms
# image 187/271 /content/datasets/-CS-FLARE-new-3/test/images/image603_jpg.rf.2b17b127cd90d07957cff5fb408582fd.jpg: 640x640 4 trees, 13.9ms
# image 223/271 /content/datasets/-CS-FLARE-new-3/test/images/image762_jpg.rf.93dea5ae8a56e6d4d7b23c03598eeaae.jpg: 640x640 1 brush, 1 grass, 4 trees, 11.8ms
# image 224/271 /content/datasets/-CS-FLARE-new-3/test/images/image771_jpg.rf.b71765ac9412a11de096f40a257aabe9.jpg: 640x640 1 grass, 2 trees, 12.2ms
# image 225/271 /content/datasets/-CS-FLARE-new-3/test/images/image777_jpg.rf.6e4ef0625d348bccf2eba4097ffcc8ce.jpg: 640x640 1 grass, 18.2ms
# image 226/271 /content/datasets/-CS-FLARE-new-3/test/images/image780_jpg.rf.7fd9301701cc5e36f31c7f1d988386ac.jpg: 640x640 1 brush, 1 grass, 1 tree, 12.8ms
# image 227/271 /content/datasets/-CS-FLARE-new-3/test/images/image794_jpg.rf.6dfb9e102fc5c2e700148bc4a0af793a.jpg: 640x640 2 grasss, 1 tree, 12.6ms
# image 228/271 /content/datasets/-CS-FLARE-new-3/test/images/image811_jpg.rf.76fc9a9779060aebac4c57cb68a2af0c.jpg: 640x640 2 trees, 12.8ms
# image 229/271 /content/datasets/-CS-FLARE-new-3/test/images/image812_jpg.rf.4513c33e9be7d94e046958bbf8a44da3.jpg: 640x640 1 tree, 12.7ms
# image 230/271 /content/datasets/-CS-FLARE-new-3/test/images/image835_jpg.rf.6054f54a06f67723392974e9e7e9dcf3.jpg: 640x640 3 grasss, 1 tree, 13.4ms
# image 231/271 /content/datasets/-CS-FLARE-new-3/test/images/image836_jpg.rf.2662d487ebe5d677bf5a635469e59313.jpg: 640x640 2 brushs, 1 tree, 13.3ms
# image 232/271 /content/datasets/-CS-FLARE-new-3/test/images/image838_jpg.rf.7228ebce401a04d8d78577cde2892954.jpg: 640x640 1 tree, 13.2ms
# image 233/271 /content/datasets/-CS-FLARE-new-3/test/images/image846_jpg.rf.9d29efa20416f8db36575dd62977614c.jpg: 640x640 1 grass, 3 trees, 9.6ms
# image 234/271 /content/datasets/-CS-FLARE-new-3/test/images/image848_jpg.rf.80cdd069133f31ad088b8cb6abb6b1d4.jpg: 640x640 3 brushs, 2 grasss, 2 trees, 9.9ms
# image 235/271 /content/datasets/-CS-FLARE-new-3/test/images/image848_jpg.rf.b292003bc3c754f515c904f27cc75089.jpg: 640x640 3 grasss, 2 trees, 9.8ms
# image 236/271 /content/datasets/-CS-FLARE-new-3/test/images/image857_jpg.rf.36cb89c2edf46c5e0682943eb33da121.jpg: 640x640 1 tree, 10.1ms
# image 237/271 /content/datasets/-CS-FLARE-new-3/test/images/image861_jpg.rf.bdb2d0655c5f3aa769c84f69aa5fbcd5.jpg: 640x640 1 brush, 1 grass, 1 tree, 12.4ms
# image 238/271 /content/datasets/-CS-FLARE-new-3/test/images/image867_jpg.rf.076875f22a0a0443eb78ac26ece1129c.jpg: 640x640 4 grasss, 2 trees, 10.2ms
# image 239/271 /content/datasets/-CS-FLARE-new-3/test/images/image883_jpg.rf.b73638c178615c9fd9a5dd2fcecbef90.jpg: 640x640 2 grasss, 2 trees, 10.2ms
# image 240/271 /content/datasets/-CS-FLARE-new-3/test/images/image899_jpg.rf.71cbc0f85e3ac395c3ea1a67295d23af.jpg: 640x640 2 trees, 10.1ms
# image 241/271 /content/datasets/-CS-FLARE-new-3/test/images/image900_jpg.rf.2dc1222112ad829084d0949720180ce0.jpg: 640x640 1 grass, 2 trees, 9.9ms
# image 242/271 /content/datasets/-CS-FLARE-new-3/test/images/image900_jpg.rf.e56518582aa9e2c76d994ce2ca9f8a66.jpg: 640x640 1 grass, 1 tree, 9.9ms
# image 243/271 /content/datasets/-CS-FLARE-new-3/test/images/image901_jpg.rf.4fc3b2df8037f0eb078b9f9d45d54bab.jpg: 640x640 2 trees, 11.0ms
# image 244/271 /content/datasets/-CS-FLARE-new-3/test/images/image907_jpg.rf.bedf5ff6117f366bfc8c611fc1c78672.jpg: 640x640 1 tree, 9.9ms
# image 245/271 /content/datasets/-CS-FLARE-new-3/test/images/image909_jpg.rf.a3e363702c245bef97d294045bd11544.jpg: 640x640 1 tree, 9.7ms
# image 246/271 /content/datasets/-CS-FLARE-new-3/test/images/image912_jpg.rf.2864694b12c48ca92e33db4d4b50cdb2.jpg: 640x640 1 brush, 1 tree, 9.7ms
# image 247/271 /content/datasets/-CS-FLARE-new-3/test/images/image917_jpg.rf.4a1018a14667cb16b0ee86174d5b7361.jpg: 640x640 1 tree, 9.6ms
# image 248/271 /content/datasets/-CS-FLARE-new-3/test/images/image918_jpg.rf.0ff1f823aa44d2654b04140b69557b32.jpg: 640x640 1 tree, 9.6ms
# image 249/271 /content/datasets/-CS-FLARE-new-3/test/images/image919_jpg.rf.7d5adb7886480ed7b8c1a0f8d3de3ec0.jpg: 640x640 1 tree, 9.7ms
# image 250/271 /content/datasets/-CS-FLARE-new-3/test/images/image922_jpg.rf.a038d280f0889aae8171af024126b82d.jpg: 640x640 1 tree, 9.9ms
# image 251/271 /content/datasets/-CS-FLARE-new-3/test/images/image924_jpg.rf.424d829789a0baaa42b7bb5c6eb1e9ac.jpg: 640x640 1 tree, 10.0ms
# image 252/271 /content/datasets/-CS-FLARE-new-3/test/images/image929_jpg.rf.4971cb9bcf942f83be6caab998474dc9.jpg: 640x640 1 leaf litter, 1 tree, 10.2ms
# image 253/271 /content/datasets/-CS-FLARE-new-3/test/images/image934_jpg.rf.24d13f90f6e6873b5ca2afd9b78fa2a9.jpg: 640x640 1 tree, 9.8ms
# image 254/271 /content/datasets/-CS-FLARE-new-3/test/images/image934_jpg.rf.864ebf1a860324af1dc1f187218c6cee.jpg: 640x640 1 tree, 9.7ms
# image 255/271 /content/datasets/-CS-FLARE-new-3/test/images/image936_jpg.rf.130f11da65b44b413e3002103e2ce7f2.jpg: 640x640 1 tree, 9.7ms
# image 256/271 /content/datasets/-CS-FLARE-new-3/test/images/image939_jpg.rf.e8101e451dbe92c4a96ebc7fdfd91e6a.jpg: 640x640 1 tree, 9.6ms
# image 257/271 /content/datasets/-CS-FLARE-new-3/test/images/image941_jpg.rf.803afd2ea9385d6f934113d4dfa93db2.jpg: 640x640 1 brush, 1 grass, 9.6ms
# image 258/271 /content/datasets/-CS-FLARE-new-3/test/images/image950_jpg.rf.b9fc2fdc3cdfb268c19a41f19338eb88.jpg: 640x640 2 grasss, 1 tree, 9.6ms
# image 259/271 /content/datasets/-CS-FLARE-new-3/test/images/image956_jpg.rf.db4d048ad41c2713e13c8a030f6137c1.jpg: 640x640 2 brushs, 1 tree, 9.7ms
# image 260/271 /content/datasets/-CS-FLARE-new-3/test/images/image959_jpg.rf.5cdb4dc7ed6ee42e579d7fd0a8d2f7c1.jpg: 640x640 1 leaf litter, 1 tree, 9.6ms
# image 261/271 /content/datasets/-CS-FLARE-new-3/test/images/image961_jpg.rf.e78116c3f8579de8dabb2cd83ba4ae29.jpg: 640x640 3 brushs, 2 trees, 9.6ms
# image 262/271 /content/datasets/-CS-FLARE-new-3/test/images/image962_jpg.rf.2a51d8f50f46c4627ac0773247e92bb7.jpg: 640x640 3 brushs, 2 trees, 9.6ms
# image 263/271 /content/datasets/-CS-FLARE-new-3/test/images/image968_jpg.rf.d157ef7221a382642e8af22db9bf0775.jpg: 640x640 1 brush, 1 tree, 9.6ms
# image 264/271 /content/datasets/-CS-FLARE-new-3/test/images/image971_jpg.rf.9397b6b55432e3b61d78be4ff9ce66d0.jpg: 640x640 1 tree, 9.6ms
# image 265/271 /content/datasets/-CS-FLARE-new-3/test/images/image980_jpg.rf.fbe7d11d57ce81a36a6ed0539bce35ab.jpg: 640x640 1 brush, 1 grass, 1 tree, 9.6ms
# image 266/271 /content/datasets/-CS-FLARE-new-3/test/images/image984_jpg.rf.89dcb8f509b82ce3405f2faff3c4c2ed.jpg: 640x640 1 grass, 10.0ms
# image 267/271 /content/datasets/-CS-FLARE-new-3/test/images/image985_jpg.rf.eeac5274a3f7e5b7bc85642e6fc225da.jpg: 640x640 2 trees, 9.6ms
# image 268/271 /content/datasets/-CS-FLARE-new-3/test/images/image989_jpg.rf.f8bdf3d7500c94ffd8f44d2744e08388.jpg: 640x640 1 tree, 9.6ms
# image 269/271 /content/datasets/-CS-FLARE-new-3/test/images/image995_jpg.rf.aff7f961b4669ab5918a3313f3e80121.jpg: 640x640 1 grass, 9.6ms
# image 270/271 /content/datasets/-CS-FLARE-new-3/test/images/image999_jpg.rf.547b041117dea058b03f60d714bec2e7.jpg: 640x640 8 brushs, 1 tree, 9.6ms
# image 271/271 /content/datasets/-CS-FLARE-new-3/test/images/image99_jpg.rf.3202d5633e9bd4eaed18424265201288.jpg: 640x640 1 brush, 2 grasss, 3 trees, 9.6ms
# Speed: 1.6ms preprocess, 11.0ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/segment/predict2/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %% [markdown]
# ## Save & Deploy model
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload and your model weights to Roboflow Deploy for autolabeling, autoscaling inference, and using later.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) supports uploading YOLOv8 weights.
#
# Run this cell to save your model weights:

# %%
project.version(dataset.version).deploy(model_type="yolov8-seg", model_path=f"{HOME}/runs/segment/train/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-54a45a66330f> in <cell line: 1>()
# ----> 1 project.version(dataset.version).deploy(model_type="yolov8-seg", model_path=f"{HOME}/runs/segment/train/")
#
# NameError: name 'project' is not defined

# %% [markdown]
# # Deploy Your Model to the Edge
#
# ![Roboflow Inference banner](https://blog.roboflow.com/content/images/2023/08/banner.png)
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv8 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv8. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
